# %% [markdown]
# <a href="https://colab.research.google.com/github/drago467/AIVN-MODULE-2/blob/main/Programming%20with%20high%20level%20syntax%20numpy%2C%201d%20data/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### numpy and matplotlib

# %%
import cv2

# Read the image
image = cv2.imread('image1.png', 1)
print(image.shape)
# Out:
# (162, 311, 3)

# %%
import cv2

# Read the image
image = cv2.imread('image2.png', 0)
print(image.shape)
# Out:
# (162, 311)

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread('image2.png', 0)

# Display the image
plt.figure(figsize=(4, 2))
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread('image1.png')

# Convert the image from BGR to RGB
# image_rgb = image[:, :, ::-1]
image_rgb = image[:, :, [2, 1, 0]]

# Display the image
plt.imshow(image_rgb)

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread('image.jpeg')

# Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.axis('off')  # Hide the axis
plt.show()
